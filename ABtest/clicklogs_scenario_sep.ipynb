# %%
import pandas as pd

# %%
df = pd.read_csv("../ABtest/editdata/scenario_merged.csv")
df
# Out:
#                           _id                    button username  \
# 0    67fc68852560c173d7061929  StartButton - scenario 1      구두자
# 1    67fc68922560c173d706192b                    공기밥 추가      구두자
# 2    67fc689c2560c173d706192d                     광운 김밥      구두자
# 3    67fc68a12560c173d706192f                     결제 버튼      구두자
# 4    67fc68c32560c173d7061931                        no      구두자
# ..                        ...                       ...      ...
# 97   67fc64ea2560c173d70618f9                     광운 김밥      차춘자
# 98   67fc64eb2560c173d70618fb                     광운 김밥      차춘자
# 99   67fc64f82560c173d70618fd                     결제 버튼      차춘자
# 100  67fc65122560c173d70618ff                        no      차춘자
# 101  67fc651a2560c173d7061901                     결제 버튼      차춘자
#
#                             timestamp  duration_sec  total_duration_sec  \
# 0    2025-04-14 01:44:37.025000+00:00         0.000              66.845
# ...

# %%
scenario1_clicklogs = df[df['scenario'] == 'scenario 1']


scenario2_clicklogs = df[df['scenario'] == 'scenario 2']

scenario1_clicklogs.to_csv('../ABtest/editdata/scenario1_clicklogs.csv', index = False)
scenario2_clicklogs.to_csv('../ABtest/editdata/scenario2_clicklogs.csv', index = False)
