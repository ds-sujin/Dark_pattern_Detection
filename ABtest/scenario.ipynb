# %%
import pandas as pd

# %%
# CSV 파일 불러오기
df = pd.read_csv('../ABtest/raw/kiosk.clicklogs.csv')

# 데이터 미리보기
# df
# scenario1_users = df[df['button'] == 'StartButton - scenario 1']['username'].unique()
# print(scenario1_users)
# df_scenario1 = df[df['username'].isin(scenario1_users)]
# df_scenario1


# scenario 2
scenario2_users = df[df['button'] == 'StartButton - scenario 2']['username'].unique()
print(scenario2_users)
# df_scenario2 = df[df['username'].isin(scenario2_users)]
# df_scenario2

# df_scenario1.to_csv('../ABtest/editdata/scenario1_clicklogs.csv', index=False, encoding='utf-8-sig')
# df_scenario2.to_csv('../ABtest/editdata/scenario2_clicklogs.csv', index=False, encoding='utf-8-sig')
# Out:
# ['조영애' '송윤희' '차춘자' '이명숙' '유기석' '이영희' '이후남' '이오범' '서정열' '김인복']

# %%
df = pd.read_csv('../ABtest/raw/체험 전 작성 사항(응답) - 설문지 응답 시트1.csv')

# %%
s1_names = ['조상동', '이옥순', '최미화', '이미령', '박정현', '한정수', '박춘악', '구두자', '이순자', '오연회']

df_s1_users = df[df["성함을 작성해주세요."].isin(s1_names)]
df_s1_users

df_s1_users.to_csv('../ABtest/editdata/scenario1_prev_test.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('../ABtest/raw/체험 전 작성 사항(응답) - 설문지 응답 시트1.csv')

df
# Out:
#                       타임스탬프 성함을 작성해주세요.  연세를 작성해주세요.  \
# 0   2025. 4. 14 오전 10:55:35         이후남           74
# 1   2025. 4. 14 오전 10:56:50         오연회           78
# 2   2025. 4. 14 오전 10:57:50         이오범           68
# 3   2025. 4. 14 오전 11:09:34         서정열           72
# 4   2025. 4. 14 오전 11:13:18         김인복           75
# 5    2025. 4. 14 오후 3:50:49         이순자           75
# 6    2025. 4. 14 오후 3:52:16         한정수           74
# 7    2025. 4. 14 오후 3:53:13         박정현           68
# 8    2025. 4. 14 오후 3:55:24         송윤희           71
# 9    2025. 4. 14 오후 3:56:46         최미화           80
# 10   2025. 4. 14 오후 3:57:48         이옥순           65
# 11   2025. 4. 14 오후 4:00:15         조영애           72
# 12   2025. 4. 14 오후 4:01:20         조상동           86
# 13   2025. 4. 14 오후 4:02:48         이미령           74
# 14   2025. 4. 14 오후 4:04:38         유기석           70
# 15   2025. 4. 14 오후 4:05:46         박춘악           88
# 16   2025. 4. 14 오후 4:07:23         차춘자           83
# ...

# %%
s2_names = ['조영애','송윤희','차춘자','이명숙','유기석','이영희','이후남','이오범','서정열','김인복']

df_s2_users = df[df["성함을 작성해주세요."].isin(s2_names)]
df_s2_users

df_s2_users.to_csv('../ABtest/editdata/scenario2_prev_test.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('../ABtest/raw/체험 후 작성 사항(응답) - 설문지 응답 시트1.csv')
df
# Out:
#                       타임스탬프   성함 화면 속 버튼이나 문구가 혼란스럽거나 이해하기 어려웠나요?  \
# 0   2025. 4. 14 오전 11:00:42  이후남                        약간 혼란스러웠음
# 1   2025. 4. 14 오전 11:03:51  이오범                          전혀 아니었음
# 2   2025. 4. 14 오전 11:04:56  오연회                          많이 헷갈렸음
# 3   2025. 4. 14 오전 11:13:58  서정열                        약간 혼란스러웠음
# 4   2025. 4. 14 오전 11:16:00  김인복                          많이 헷갈렸음
# 5    2025. 4. 14 오후 3:51:51  이순자                          많이 헷갈렸음
# 6    2025. 4. 14 오후 3:52:53  한정수                          많이 헷갈렸음
# 7    2025. 4. 14 오후 3:54:27  박정현                        약간 혼란스러웠음
# 8    2025. 4. 14 오후 3:55:58  송윤희                          전혀 아니었음
# 9    2025. 4. 14 오후 3:57:20  최미화                          많이 헷갈렸음
# 10   2025. 4. 14 오후 3:59:14  이옥순                          전혀 아니었음
# 11   2025. 4. 14 오후 4:00:49  조영애                          전혀 아니었음
# 12   2025. 4. 14 오후 4:02:16  조상동                          전혀 아니었음
# ...

# %%
s1_names = ['조상동', '이옥순', '최미화', '이미령', '박정현', '한정수', '박춘악', '구두자', '이순자', '오연회']

df_s1_users = df[df["성함"].isin(s1_names)]
df_s1_users

df_s1_users.to_csv('../ABtest/editdata/scenario1_post_test.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('../ABtest/raw/체험 후 작성 사항(응답) - 설문지 응답 시트1.csv')
df
# Out:
#                       타임스탬프   성함 화면 속 버튼이나 문구가 혼란스럽거나 이해하기 어려웠나요?  \
# 0   2025. 4. 14 오전 11:00:42  이후남                        약간 혼란스러웠음
# 1   2025. 4. 14 오전 11:03:51  이오범                          전혀 아니었음
# 2   2025. 4. 14 오전 11:04:56  오연회                          많이 헷갈렸음
# 3   2025. 4. 14 오전 11:13:58  서정열                        약간 혼란스러웠음
# 4   2025. 4. 14 오전 11:16:00  김인복                          많이 헷갈렸음
# 5    2025. 4. 14 오후 3:51:51  이순자                          많이 헷갈렸음
# 6    2025. 4. 14 오후 3:52:53  한정수                          많이 헷갈렸음
# 7    2025. 4. 14 오후 3:54:27  박정현                        약간 혼란스러웠음
# 8    2025. 4. 14 오후 3:55:58  송윤희                          전혀 아니었음
# 9    2025. 4. 14 오후 3:57:20  최미화                          많이 헷갈렸음
# 10   2025. 4. 14 오후 3:59:14  이옥순                          전혀 아니었음
# 11   2025. 4. 14 오후 4:00:49  조영애                          전혀 아니었음
# 12   2025. 4. 14 오후 4:02:16  조상동                          전혀 아니었음
# ...

# %%
s2_names = ['조영애','송윤희','차춘자','이명숙','유기석','이영희','이후남','이오범','서정열','김인복']

df_s2_users = df[df["성함"].isin(s2_names)]
df_s2_users

df_s2_users.to_csv('../ABtest/editdata/scenario2_post_test.csv', index=False, encoding='utf-8-sig')
