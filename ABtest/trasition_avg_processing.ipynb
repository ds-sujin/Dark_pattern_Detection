# %%
import pandas as pd

# %%
df = pd.read_csv("../ABtest/editdata/scenario1_clicklogs.csv")
df
# Out:
#                          _id                    button username  \
# 0   67fc68852560c173d7061929  StartButton - scenario 1      구두자
# 1   67fc68922560c173d706192b                    공기밥 추가      구두자
# 2   67fc689c2560c173d706192d                     광운 김밥      구두자
# 3   67fc68a12560c173d706192f                     결제 버튼      구두자
# 4   67fc68c32560c173d7061931                        no      구두자
# 5   67fc68c72560c173d7061933                     결제 버튼      구두자
# 6   67fc63da2560c173d70618eb  StartButton - scenario 1      박정현
# 7   67fc63df2560c173d70618ed                       돈까스      박정현
# 8   67fc63e12560c173d70618ef                       돈까스      박정현
# 9   67fc63e82560c173d70618f1                     결제 버튼      박정현
# 10  67fc63ef2560c173d70618f3                        no      박정현
# 11  67fc63f52560c173d70618f5                     결제 버튼      박정현
# 12  67fc672a2560c173d7061915  StartButton - scenario 1      박춘악
# 13  67fc67382560c173d7061917                       돈까스      박춘악
# 14  67fc674d2560c173d7061919                     결제 버튼      박춘악
# 15  67fc67632560c173d706191b                       yes      박춘악
# 16  67fc6bbc2560c173d7061951  StartButton - scenario 1      오연회
# 17  67fc6bcd2560c173d7061953                     광운 김밥      오연회
# 18  67fc6bd42560c173d7061955                     결제 버튼      오연회
# 19  67fc6bfd2560c173d7061957                        no      오연회
# 20  67fc6c062560c173d7061959                     결제 버튼      오연회
# 21  67fc62e52560c173d70618d9  StartButton - scenario 1      이미령
# 22  67fc62ef2560c173d70618db                      된장찌개      이미령
# 23  67fc62f32560c173d70618dd                     결제 버튼      이미령
# 24  67fc62f82560c173d70618df                       yes      이미령
# 25  67fc69962560c173d706193f  StartButton - scenario 1      이순자
# 26  67fc699f2560c173d7061941                     광운 김밥      이순자
# 27  67fc69c02560c173d7061943                     결제 버튼      이순자
# 28  67fc69d12560c173d7061945                       yes      이순자
# 29  67fc62412560c173d70618c1  StartButton - scenario 1      이옥순
# 30  67fc62452560c173d70618c3                       돈까스      이옥순
# 31  67fc62462560c173d70618c5                       돈까스      이옥순
# 32  67fc624a2560c173d70618c7                     결제 버튼      이옥순
# 33  67fc624d2560c173d70618c9                        no      이옥순
# 34  67fc624e2560c173d70618cb                     결제 버튼      이옥순
# 35  67fc61872560c173d70618ad  StartButton - scenario 1      조상동
# 36  67fc61942560c173d70618af                     광운 김밥      조상동
# 37  67fc61972560c173d70618b1                     결제 버튼      조상동
# 38  67fc61d42560c173d70618b3                       yes      조상동
# 39  67fc62732560c173d70618cd  StartButton - scenario 1      최미화
# 40  67fc627c2560c173d70618cf                     광운 김밥      최미화
# 41  67fc627e2560c173d70618d1                     광운 김밥      최미화
# 42  67fc62882560c173d70618d3                     결제 버튼      최미화
# 43  67fc62992560c173d70618d5                        no      최미화
# 38  2025-04-14 01:16:04.843000+00:00        61.377              77.850
# 39  2025-04-14 01:18:43.583000+00:00         0.000              40.011
# 40  2025-04-14 01:18:52.190000+00:00         8.607              40.011
# 41  2025-04-14 01:18:54.408000+00:00         2.218              40.011
# 42  2025-04-14 01:19:04.768000+00:00        10.360              40.011
# 43  2025-04-14 01:19:21.043000+00:00        16.275              40.011
# 44  2025-04-14 01:19:23.594000+00:00         2.551              40.011
# 45  2025-04-14 01:32:13.506000+00:00         0.000              28.597
# 46  2025-04-14 01:32:18.275000+00:00         4.769              28.597
# 47  2025-04-14 01:32:22.909000+00:00         4.634              28.597
# 48  2025-04-14 01:32:42.103000+00:00        19.194              28.597
#
#       scenario
# 0   scenario 1
# 1   scenario 1
# 2   scenario 1
# 3   scenario 1
# 4   scenario 1
# 5   scenario 1
# 6   scenario 1
# 7   scenario 1
# 8   scenario 1
# 9   scenario 1
# 10  scenario 1
# 11  scenario 1
# 12  scenario 1
# 13  scenario 1
# 14  scenario 1
# 15  scenario 1
# 16  scenario 1
# 17  scenario 1
# 18  scenario 1
# 19  scenario 1
# 20  scenario 1
# 21  scenario 1
# 22  scenario 1
# 23  scenario 1
# 24  scenario 1
# 25  scenario 1
# 26  scenario 1
# 27  scenario 1
# 28  scenario 1
# 29  scenario 1
# 30  scenario 1
# 31  scenario 1
# 32  scenario 1
# 33  scenario 1
# 34  scenario 1
# 35  scenario 1
# 36  scenario 1
# 37  scenario 1
# 38  scenario 1
# 39  scenario 1
# 40  scenario 1
# 41  scenario 1
# 42  scenario 1
# 43  scenario 1
# 44  scenario 1
# 45  scenario 1
# 46  scenario 1
# 47  scenario 1
# 48  scenario 1

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.sort_values(by=["username", "timestamp"])

# 사용자별로 처리
def get_first_response_and_time(user_df):
    user_df = user_df.reset_index(drop=True)
    for i in range(len(user_df) - 1):
        curr_btn = user_df.loc[i, "button"]
        next_btn = user_df.loc[i + 1, "button"]
        
        if curr_btn == "결제 버튼" and next_btn in ["yes", "no"]:
            time_diff = (user_df.loc[i + 1, "timestamp"] - user_df.loc[i, "timestamp"]).total_seconds()
            return pd.Series([next_btn, time_diff])
    return pd.Series(["응답 없음", None])

# 그룹별 적용
results = df.groupby("username").apply(get_first_response_and_time).reset_index()
results.columns = ["username", "결제 응답", "응답까지 걸린 시간 (초)"]

# 출력
print(results)
# Out:
# C:\Users\82103\AppData\Local\Temp\ipykernel_13068\2194105148.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   results = df.groupby("username").apply(get_payment_response).reset_index()
#   username 결제 응답
# 0      구두자    no
# 1      박정현    no
# 2      박춘악   yes
# 3      오연회    no
# 4      이미령   yes
# 5      이순자   yes
# 6      이옥순    no
# 7      조상동   yes
# 8      최미화    no
# 9      한정수   yes
